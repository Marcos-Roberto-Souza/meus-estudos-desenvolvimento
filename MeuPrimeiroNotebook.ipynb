# %% [raw]
# Teste de uma lnha no tipo raw

# %% [markdown]
# # Meu primeiro título em Markdown!
# ## Um subtítulo qualquer

# %%
print("Hello World")
# Out:
# Hello World

# %%
# Revisão
nome = 'Joaquim'
idade = 34
valor_em_carteira = 345.99
vip = True # False

print(f'My name is: {nome}\nMy years is: {idade}\nMy Money is: {valor_em_carteira}\nI am: {vip}')
# Out:
# My name is: Joaquim
# My years is: 34
# My Money is: 345.99
# I am: True

# %%
# Revisando Função
def soma_dois_valores(primeiro, segundo):
    resultado = primeiro + segundo
    return resultado

# valor_1 = 10
# valor_2 = 20

valor_1 = "Marcos "
valor_2 = "Roberto"

soma = soma_dois_valores(valor_1, valor_2)

print(soma)
# Out:
# Marcos Roberto

# %%
lista_clientes = ['Joaquim', 'José', 'João', 'Maria']
lista_produtos = ['Maçã', 'Banana', 'Chocolate']

lista_clientes.append('Roberta')

print(lista_clientes[4])
# Out:
# Roberta
