# %%
import pandas as pd

df_csv = pd.read_csv('python-diferentes-formatos-dados/cidades.csv')
df_csv.head()
# Out:
#    ranking       municipio                uf   populacao
# 0        1       São Paulo         São Paulo  11 451 999
# 1        2  Rio de Janeiro    Rio de Janeiro   6 211 223
# 2        3        Brasília  Distrito Federal   2 817 381
# 3        4       Fortaleza             Ceará   2 428 708
# 4        5        Salvador             Bahia   2 417 678

# %%
df_hash_csv = pd.read_csv('python-diferentes-formatos-dados/cidades_separado_por_hashtag.csv', sep='#', header=None)
df_hash_csv.head()
# Out:
#          0               1                 2           3
# 0  ranking       municipio                uf   populacao
# 1        1       São Paulo         São Paulo  11 451 999
# 2        2  Rio de Janeiro    Rio de Janeiro   6 211 223
# 3        3        Brasília  Distrito Federal   2 817 381
# 4        4       Fortaleza             Ceará   2 428 708

# %%
df_hash_csv.to_csv('csv_salvo.csv')

# %%
import pandas as pd

df_excel = pd.read_excel('python-diferentes-formatos-dados/cidades.xlsx', 'Populacao')
df_excel.head()
# Out:
#    ranking       municipio                uf   populacao
# 0        1       São Paulo         São Paulo  11 451 999
# 1        2  Rio de Janeiro    Rio de Janeiro   6 211 223
# 2        3        Brasília  Distrito Federal   2 817 381
# 3        4       Fortaleza             Ceará   2 428 708
# 4        5        Salvador             Bahia   2 417 678

# %%
df_excel.to_excel('excel.xlsx', index=False)

# %%
df_json = pd.read_json('python-diferentes-formatos-dados/cidades.json')
df_json.head()
# Out:
#    ranking       municipio                uf   populacao
# 0        1       São Paulo         São Paulo  11 451 999
# 1        2  Rio de Janeiro    Rio de Janeiro   6 211 223
# 2        3        Brasília  Distrito Federal   2 817 381
# 3        4       Fortaleza             Ceará   2 428 708
# 4        5        Salvador             Bahia   2 417 678

# %%
df_json.to_json('meu.json', indent=4, orient='records')

# %%
df_xml = pd.read_xml('python-diferentes-formatos-dados/cidades.xml')
df_xml.head()
# Out:
#    ranking       municipio                uf   populacao
# 0        1       São Paulo         São Paulo  11 451 999
# 1        2  Rio de Janeiro    Rio de Janeiro   6 211 223
# 2        3        Brasília  Distrito Federal   2 817 381
# 3        4       Fortaleza             Ceará   2 428 708
# 4        5        Salvador             Bahia   2 417 678

# %%
df_xml.to_xml('meu.xml')

# %%
df_html = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_mucic%C3%ADpios_do_Brasil_acima_de_cem_mil_habitantes_(2022)')
df_html[0].head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df_html = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_mucic%C3%ADpios_do_Brasil_acima_de_cem_mil_habitantes_(2022)')
#       2 df_html[0].head()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\html.py:1226, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1222 check_dtype_backend(dtype_backend)
#    1224 io = stringify_path(io)
# -> 1226 return _parse(
#    1227     flavor=flavor,
#    1228     io=io,
#    1229     match=match,
#    1230     header=header,
#    1231     index_col=index_col,
#    1232     skiprows=skiprows,
#    1233     parse_dates=parse_dates,
# ...

# %%
df_html[0].to_html('meu.html'
