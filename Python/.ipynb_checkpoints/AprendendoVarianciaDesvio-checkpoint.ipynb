# %% [markdown]
# # Análise quantitativa de dados com Pandas

# %% [markdown]
# ### Compreendendo Variância e Desvio Padrão

# %%
import statistics

lst1 = [0, 1, 2, 3, 3, 3, 4, 4, 4, 5, 5, 6]
lst2 = [0, -1, -2, 30, 3, 3,4, 40, 4, -50, 5, 6]

print(f'Média lista 1: {statistics.mean(lst1)}')
print(f'Média lista 2: {statistics.mean(lst2)}')
# Out:
# Média lista 1: 3.3333333333333335
# Média lista 2: 3.5

# %%
statistics.variance(lst1)
# Out:
# 2.9696969696969697

# %%
statistics.variance(lst2)
# Out:
# 451.72727272727275

# %%
sorted(lst2)
# Out:
# [-50, -2, -1, 0, 3, 3, 4, 4, 5, 6, 30, 40]

# %%
m = statistics.mean(lst2)
m
# Out:
# 3.5

# %%
dp = statistics.stdev(lst2)
dp
# Out:
# 21.253876651737507

# %%
m - dp, m + dp # faixa 1 desvio padrão
# Out:
# (-17.753876651737507, 24.753876651737507)

# %%
m - 2 * dp, m + 2*dp # faixa 2 desvio padrão
# Out:
# (-39.00775330347501, 46.00775330347501)

# %% [markdown]
# ### Variância e Desvio Padrão no Pandas

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('diabetes.csv')

# %%
diabetes[['idade', 'imc']]
# Out:
#      idade   imc
# 0       50  33.6
# 1       31  26.6
# 2       32  23.3
# 3       21  28.1
# 4       33  43.1
# ..     ...   ...
# 763     63  32.9
# 764     27  36.8
# 765     30  26.2
# 766     47  30.1
# 767     23  30.4
#
# [768 rows x 2 columns]

# %%
diabetes['idade'].var()
# Out:
# np.float64(138.30304589037377)

# %%
diabetes[['idade', 'imc']].std()
# Out:
# idade    11.760232
# imc       6.924988
# dtype: float64

# %%
diabetes[['idade', 'imc']].mean()
# Out:
# idade    33.240885
# imc      32.457464
# dtype: float64

# %%
diabetes['imc'].var()
# Out:
# np.float64(47.955463399802895)
